# %% [markdown]
# **1.Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.**

# %% [markdown]
# Given:
#
# 𝑇
# (
# 𝑛
# )
# =
# 3
# 𝑇
# (
# 𝑛
# −
# 1
# )
# +
# 12
# 𝑛
# T(n)=3T(n−1)+12n
# 𝑇
# (
# 0
# )
# =
# 5
#
# T(0)=5

# %% [markdown]
# I understand you'd like me to provide answers with explanations for the questions in the "Recursssion Releation" assignment. I'll go through each question one by one.
#
# 1. For T(n) = 3T(n-1) + 12n, with T(0) = 5, find T(2):
#
# Let's solve this step by step:
#
# 1) First, we need to find T(1):
#    T(1) = 3T(0) + 12(1)
#    T(1) = 3(5) + 12 = 15 + 12 = 27
#
# 2) Now we can find T(2):
#    T(2) = 3T(1) + 12(2)
#    T(2) = 3(27) + 24 = 81 + 24 = 105
#
# Therefore, T(2) = 105.
#
#
#
# **2. Solving recurrence relations using the substitution method:**
#
# a. T(n) = T(n-1) + c
#
# Let's assume T(n) = an + b, where a and b are constants we need to find.
#
# T(n) = T(n-1) + c
# an + b = a(n-1) + b + c
# an + b = an - a + b + c
#
# Equating coefficients:
# a = a (satisfied)
# b = -a + b + c
# 0 = -a + c
# a = c
#
# So, T(n) = cn + b
#
# To find b, we need an initial condition. Let's say T(0) = k
# k = c(0) + b
# b = k
#
# Therefore, the solution is T(n) = cn + k, where k is the initial value of T(0).
#
# b. T(n) = 2T(n/2) + n
#
# Let's assume T(n) = an log n + bn, where a and b are constants we need to find.
#
# T(n) = 2T(n/2) + n
# an log n + bn = 2(a(n/2) log(n/2) + b(n/2)) + n
# an log n + bn = an log(n/2) + an + bn + n
# an log n + bn = an log n - an + an + bn + n
# 0 = -an + n
# a = 1
#
# So, T(n) = n log n + bn
#
# To find b, we substitute back into the original equation:
# n log n + bn = 2((n/2) log(n/2) + b(n/2)) + n
# n log n + bn = n log n - n + bn + n
# 0 = 0 (satisfied for any b)
#
# Therefore, the solution is T(n) = n log n + cn, where c is a constant that depends on the initial condition.
#
# c. T(n) = 2T(n/2) + c
#
# Let's assume T(n) = an log n + b, where a and b are constants we need to find.
#
# T(n) = 2T(n/2) + c
# an log n + b = 2(a(n/2) log(n/2) + b) + c
# an log n + b = an log n - an + 2b + c
# 0 = -an + b + c
# an = b + c
#
# This should be true for all n, so a = 0 and b = -c.
#
# Therefore, the solution is T(n) = c log n + b, where b depends on the initial condition.
#
# d. T(n) = T(n/2) + c
#
# Let's assume T(n) = a log n + b, where a and b are constants we need to find.
#
# T(n) = T(n/2) + c
# a log n + b = a log(n/2) + b + c
# a log n + b = a log n - a + b + c
# 0 = -a + c
# a = c
#
# Therefore, the solution is T(n) = c log n + b, where b depends on the initial condition.
#
#
#
#
# **3. Solving recurrence relations using the recursive tree approach:**
#
# a. T(n) = 2T(n-1) + 1
#
# Let's draw the recursive tree:
#
#                    n
#                  /   \
#             n-1       n-1
#            /   \     /   \
#         n-2   n-2  n-2  n-2
#          .     .    .    .
#          .     .    .    .
#
# At each level, we're adding 1.
# Number of nodes at level i: 2^i
# Value at each node at level i: 1
#
# Total sum = 1 + 2 + 4 + ... + 2^(n-1) = 2^n - 1
#
# Therefore, T(n) = 2^n - 1
#
# b. T(n) = 2T(n/2) + n
#
# Let's draw the recursive tree:
#
#                 n
#               /   \
#             n/2   n/2
#            /  \   /  \
#          n/4  n/4 n/4 n/4
#           .    .   .   .
#           .    .   .   .
#
# At each level, we're adding n.
# Number of levels: log n (base 2)
#
# Sum at each level:
# Level 0: n
# Level 1: n
# Level 2: n
# ...
# Level log n: n
#
# Total sum = n * log n
#
# Therefore, T(n) = n log n + cn, where c is a constant that depends on the base case.
#
# These solutions provide a comprehensive explanation for each question in the assignment. Let me know if you need any clarification or have any further questions!
